# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
beijing_airbnb = pd.read_csv("beijing.csv")
shanghai_airbnb = pd.read_csv("shanghai.csv")
hongkong_airbnb = pd.read_csv("hongkong.csv")

# %%
hongkong_airbnb
# Out:
#              id                                             name    host_id  \
# 0         69074  Beautiful oasis of plants & art @ best location     160139
# 1         75083                      SoHo off Hollywood Road  3B     304876
# 2        103760    Central Centre 5 min walk to/from Central MTR     304876
# 3        132773               Fabulous 2 Bdrm Aprt Open kitchen      304876
# 4        133390                   Soho, Hong Kong 1 bedroom flat     654642
# ...         ...                                              ...        ...
# 11444  43448438                                             刘楠的家  346350942
# 11445  43448967                                             高端公寓  346354383
# 11446  43457444                                       長洲中心里地下1號房   46439433
# 11447  43457853                                       長洲中心里地下2號房   46439433
# 11448  43463944         Lux 1 bedroom flat in center of Wan Chai   45858469
#
# ...
